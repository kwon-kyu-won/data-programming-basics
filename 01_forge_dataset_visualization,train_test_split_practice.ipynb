# %%
# !pip install mglearn
# Out:
# Requirement already satisfied: mglearn in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (2.4.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (3.10.8)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (1.8.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (3.0.0)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (12.1.1)
# Requirement already satisfied: cycler in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (0.12.1)
# Requirement already satisfied: imageio in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (2.37.3)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from mglearn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from matplotlib->mglearn) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from matplotlib->mglearn) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from matplotlib->mglearn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from matplotlib->mglearn) (25.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from matplotlib->mglearn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from matplotlib->mglearn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mglearn) (1.17.0)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from scikit-learn->mglearn) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/ds_study/lib/python3.11/site-packages (from scikit-learn->mglearn) (3.5.0)

# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
#generate dataset
X,y = mglearn.datasets.make_forge()
#plot dataset
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4) # 범례 추가
plt.xlabel("First feature")              # x축 이름
plt.ylabel("Second feature")             # y축 이름
print("X.shape: {}".format(X.shape))     # 데이터 구조 출력
# Out:
# X.shape: (26, 2)

# %%
#test_size=7: 테스트용 데이터를 정확히 7개만 뽑겠다는 뜻.
#random_state=2021: 무작위로 섞을 때 난수시드 고정. 이 숫자를 똑같이 쓰면 다음에 실행해도 항상 같은 데이터들로 나뉨.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=7, random_state=2021)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(y_test)
# Out:
# (19, 2) (19,)
# (7, 2) (7,)
# [1 0 1 0 1 1 0]

# %%
#test_size=0.2: 정수가 아닌 소수를 넣으면 비율(20%)을 의미
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(y_test)
# Out:
# (20, 2) (20,)
# (6, 2) (6,)
# [1 0 1 0 1 1]

# %%
#stratify =y: 타겟 데이터(y)의 클래스 비율(예: 0이 50%, 1이 50%)을 훈련 세트와 테스트 세트에서도 그대로 유지하도록 나눔.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2021)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(y_test)
# Out:
# (20, 2) (20,)
# (6, 2) (6,)
# [1 1 0 0 1 0]
